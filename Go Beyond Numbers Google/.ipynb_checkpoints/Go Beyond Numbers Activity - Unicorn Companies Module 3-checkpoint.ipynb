# %% [markdown]
# # Activity: Discover what is in your dataset

# %% [markdown]
# ## Introduction
#
# In this activity, you will discover characteristics of a dataset and use visualizations to analyze the data. This will develop and strengthen your skills in **exploratory data analysis (EDA)** and your knowledge of functions that allow you to explore and visualize data.
#
# EDA is an essential process in a data science workflow. As a data professional, you will need to conduct this process to better understand the data at hand and determine how it can be used to solve the problem you want to address. This activity will give you an opportunity to practice that process and prepare you for EDA in future projects.
#
# In this activity, you are a member of an analytics team that provides insights to an investing firm. To help them decide which companies to invest in next, the firm wants insights into **unicorn companies**–companies that are valued at over one billion dollars. The data you will use for this task provides information on over 1,000 unicorn companies, including their industry, country, year founded, and select investors. You will use this information to gain insights into how and when companies reach this prestigious milestone and to make recommendations for next steps to the investing firm.

# %% [markdown]
# ## Step 1: Imports

# %% [markdown]
# ### Import libraries and packages
#
# First, import relevant Python libraries and modules. Use the `pandas` library and the `matplotlib.pyplot` module.

# %%
# Import libraries and packages

import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load the dataset into a DataFrame
#
# The dataset provided is in the form of a csv file named `Unicorn_Companies.csv` and contains a subset of data on unicorn companies. As shown in this cell, the dataset has been automatically loaded in for you. You do not need to download the .csv file, or provide more code, in order to access the dataset and proceed with this lab. Please continue with this activity by completing the following instructions.

# %%
# RUN THIS CELL TO IMPORT YOUR DATA.

### YOUR CODE HERE ###
companies = pd.read_csv("Unicorn_Companies.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <cell line: 4>()
#       1 # RUN THIS CELL TO IMPORT YOUR DATA.
#       2
#       3 ### YOUR CODE HERE ###
# ----> 4 companies = pd.read_csv("Unicorn_Companies.csv")
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File ~\anaconda3\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Unicorn_Companies.csv'

# %% [markdown]
# <details>
#   <summary><h4><strong>Hint 1</strong></h4></summary>
#
# Refer to what you learned about [loading data](https://www.coursera.org/learn/go-beyond-the-numbers-translate-data-into-insight/supplement/MdTG2/reference-guide-import-datasets-using-python) in Python.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Hint 2</strong></h4></summary>
#
# Use the function in the `pandas` library that allows you to read data from a csv file and load the data into a DataFrame.
#
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Hint 3</strong></h4></summary>
#
# Use the `read_csv()` function from the `pandas` library.
#
# </details>

# %% [markdown]
# ## Step 2: Data exploration

# %% [markdown]
# ### Display the first 10 rows of the data
#
# Next, explore the dataset and answer questions to guide your exploration and analysis of the data. To begin, display the first 10 rows of the data to get an understanding of how the dataset is structured.

# %%
# Display the first 10 rows of the data

companies.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 3>()
#       1 # Display the first 10 rows of the data
# ----> 3 companies.head(10)
#
# NameError: name 'companies' is not defined

# %% [markdown]
# <details>
#   <summary><h4><strong>Hint 1</strong></h4></summary>
#
# Refer to [the content about exploratory data analysis in Python](https://www.coursera.org/learn/go-beyond-the-numbers-translate-data-into-insight/lecture/kfl9b/find-stories-using-the-six-exploratory-data-analysis-practices).
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Hint 2</strong></h4></summary>
#
# Use the function in the `pandas` library that allows you to get a specific number of rows from the top of a DataFrame.
#
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Hint 3</strong></h4></summary>
#
# Use the `head()` function from the `pandas` library.
#
# </details>

# %% [markdown]
# **Question:** What do you think the "Date Joined" column represents?

# %% [markdown]
#  Date Joined column might refers to entrance date in a holding

# %% [markdown]
# **Question:** What do you think the "Select Investors" column represents?

# %% [markdown]
# Investors that had acquired those companies

# %% [markdown]
# ### Assess the size of the dataset
#
# Get a sense of how large the dataset is. The `size` property that DataFrames have can help.

# %%
# How large the dataset is

companies.size
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 3>()
#       1 # How large the dataset is
# ----> 3 companies.size
#
# NameError: name 'companies' is not defined

# %% [markdown]
# **Question:** What do you notice about the size of the dataset?

# %% [markdown]
# small dataset with over 1000 rows.

# %% [markdown]
# ### Determine the shape of the dataset
#
# Identify the number of rows and columns in the dataset. The `shape` property that DataFrames have can help.

# %%
# Shape of the dataset

companies.shape
# Out:
# (1074, 10)

# %% [markdown]
# **Question:** What do you notice about the shape of the dataset?

# %% [markdown]
# small dataset with over 1000 rows.

# %% [markdown]
# ### Get basic information about the dataset
#
# To further understand what the dataset entails, get basic information about the dataset, including the data type of values in each column. There is more than one way to approach this task. In this instance, use the `info()` function from `pandas`.

# %%
# Get information

companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   object
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country/Region    1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 84.0+ KB

# %% [markdown]
# **Question:** What do you notice about the type of data in the `Year Founded` column? Refer to the output from using `info()` above. Knowing the data type of this variable is helpful because it indicates what types of analysis can be done with that variable, how it can be aggregated with other variables, and so on.

# %% [markdown]
# From this column, the analyst will be able to make temporal series.

# %% [markdown]
# **Question:** What do you notice about the type of data in the `Date Joined` column? Refer to the output from using `info()` above. Knowing the data type of this variable is helpful because it indicates what types of analysis can be done with that variable and how the variable can be transformed to suit specific tasks.

# %% [markdown]
# It should changed the dtype to datetime

# %% [markdown]
# ## Step 3: Statistical tests

# %% [markdown]
# ### Find descriptive statistics
#
# Find descriptive statistics and structure your dataset. The `describe()` function from the `pandas` library can help. This function generates statistics for the numeric columns in a dataset.

# %%
# Get descriptive statistics

companies.describe()
# Out:
#        Year Founded
# count   1074.000000
# mean    2012.895717
# std        5.698573
# min     1919.000000
# 25%     2011.000000
# 50%     2014.000000
# 75%     2016.000000
# max     2021.000000

# %% [markdown]
# **Question:** Based on the table of descriptive stats generated above, what do you notice about the minimum value in the `Year Founded` column? This is important to know because it helps you understand how early the entries in the data begin.

# %% [markdown]
# It could be an error data

# %% [markdown]
# **Question:** What do you notice about the maximum value in the `Year Founded` column? This is important to know because it helps you understand the most recent year captured by the data.

# %% [markdown]
# Most recent year is 2021

# %% [markdown]
# ### Convert the `Date Joined` column to datetime
#
# Use the `to_datetime()` function from the `pandas` library  to convert the `Date Joined` column to datetime. This splits each value into year, month, and date components. This is an important step in data cleaning, as it makes the data in this column easier to use in tasks you may encounter. To name a few examples, you may need to compare "date joined" between companies or determine how long it took a company to become a unicorn. Having "date joined" in datetime form would help you complete such tasks.

# %%
# Step 1: Use pd.to_datetime() to convert Date Joined column to datetime 
# Step 2: Update the column with the converted values

companies['Date Joined'] = pd.to_datetime(companies['Date Joined'])

# %%
# Use .info() to confirm that the update actually took place

companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   datetime64[ns]
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country/Region    1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 84.0+ KB

# %% [markdown]
# ### Create a `Year Joined` column
#
# It is common to encounter situations where you will need to compare the year joined with the year founded. The `Date Joined` column does not just have year—it has the year, month, and date. Extract the year component from the `Date Joined` column and add those year components into a new column to keep track of each company's year joined.

# %%
# Step 1: Use .dt.year to extract year component from Date Joined column
# Step 2: Add the result as a new column named Year Joined to the DataFrame

companies['Year'] = companies['Date Joined'].dt.year

# %%
# Use .head() to confirm that the new column did get added

companies.head(10)
# Out:
#         Company Valuation Date Joined                             Industry  \
# 0     Bytedance     $180B  2017-04-07              Artificial intelligence
# 1        SpaceX     $100B  2012-12-01                                Other
# 2         SHEIN     $100B  2018-07-03      E-commerce & direct-to-consumer
# 3        Stripe      $95B  2014-01-23                              Fintech
# 4        Klarna      $46B  2011-12-12                              Fintech
# 5         Canva      $40B  2018-01-08         Internet software & services
# 6  Checkout.com      $40B  2019-05-02                              Fintech
# 7     Instacart      $39B  2014-12-30  Supply chain, logistics, & delivery
# 8     JUUL Labs      $38B  2017-12-20                    Consumer & retail
# 9    Databricks      $38B  2019-02-05          Data management & analytics
#
#             City  Country/Region      Continent  Year Founded Funding  \
# 0        Beijing           China           Asia          2012     $8B
# 1      Hawthorne   United States  North America          2002     $7B
# 2       Shenzhen           China           Asia          2008     $2B
# 3  San Francisco   United States  North America          2010     $2B
# 4      Stockholm          Sweden         Europe          2005     $4B
# 5    Surry Hills       Australia        Oceania          2012   $572M
# 6         London  United Kingdom         Europe          2012     $2B
# 7  San Francisco   United States  North America          2012     $3B
# 8  San Francisco   United States  North America          2015    $14B
# 9  San Francisco   United States  North America          2013     $3B
#
#                                     Select Investors  Year
# 0  Sequoia Capital China, SIG Asia Investments, S...  2017
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...  2012
# 2  Tiger Global Management, Sequoia Capital China...  2018
# 3        Khosla Ventures, LowercaseCapital, capitalG  2014
# 4  Institutional Venture Partners, Sequoia Capita...  2011
# 5  Sequoia Capital China, Blackbird Ventures, Mat...  2018
# 6  Tiger Global Management, Insight Partners, DST...  2019
# 7  Khosla Ventures, Kleiner Perkins Caufield & By...  2014
# 8                            Tiger Global Management  2017
# 9  Andreessen Horowitz, New Enterprise Associates...  2019

# %% [markdown]
# ## Step 4: Results and evaluation

# %% [markdown]
# ### Take a sample of the data
#
# It is not necessary to take a sample of the data in order to conduct the visualizations and EDA that follow. But you may encounter scenarios in the future where you will need to take a sample of the data due to time and resource limitations. For the purpose of developing your skills around sampling, take a sample of the data and work with that sample for the next steps of analysis you want to conduct. Use the `sample()` function for this task.
#
# - Use `sample()` with the `n` parameter set to `50` to randomly sample 50 unicorn companies from the data. Be sure to specify the `random_state` parameter to ensure reproducibility of your work. Save the result to a variable called `companies_sampled`.

# %%
# Sample the data

companies_sampled = companies.sample(n = 50, random_state = 42)
companies_sampled
# Out:
#                 Company Valuation Date Joined  \
# 458            Zhubajie       $2B     6/16/15
# 951            Lamabang       $1B      3/6/15
# 558         Divvy Homes       $2B     8/13/21
# 653               Yiguo       $1B     11/9/16
# 146      Trade Republic       $5B     5/20/21
# 815               Enpal       $1B    10/18/21
# 167                ZEPZ       $5B     8/23/21
# 67                  N26       $9B     1/10/19
# 424             Uplight       $2B      3/3/21
# 879          BlueVoyant       $1B     2/23/22
# 103            Easyhome       $6B     2/12/18
# 198                Noom       $4B     5/24/21
# 362                Cgtz       $2B     2/21/17
# 862            Amperity       $1B     7/13/21
# 409              MOLOCO       $2B     4/29/21
# 201           ShareChat       $4B      4/8/21
# 181             Commure       $4B     9/16/21
# 140             Anduril       $5B     9/11/19
# 341            KK Group       $3B    10/23/19
# 806              At-Bay       $1B     7/27/21
# 448           Infinidat       $2B     4/29/15
# 560               Druva       $2B     6/20/19
# 982     Noname Security       $1B    12/15/21
# 203           VAST Data       $4B     4/16/20
# 3                Stripe      $95B     1/23/14
# 106           Airwallex       $6B     3/25/19
# 786              Qumulo       $1B     7/16/20
# 320           Nuvemshop       $3B     8/17/21
# 655     Yipin Shengxian       $1B     3/11/19
# 377           BGL Group       $2B    11/24/17
# 150              6Sense       $5B     3/30/21
# 694          Deliverect       $1B     1/24/22
# 704                Papa       $1B     11/4/21
# 628           LifeMiles       $1B     7/13/15
# 927                Groq       $1B     4/14/21
# 68              Klaviyo       $9B    11/17/20
# 820   Gaussian Robotics       $1B    11/10/21
# 854           58 Daojia       $1B    10/12/15
# 545           AppsFlyer       $2B     1/21/20
# 737              Island       $1B     3/23/22
# 792           Workhuman       $1B     6/23/20
# 338        Grafana Labs       $3B     3/25/21
# 1009       Red Ventures       $1B      1/7/15
# 99               Gemini       $7B    11/19/21
# 603           56PINGTAI       $1B     1/25/21
# 963         Masterworks       $1B     10/5/21
# 594                Tier       $2B    10/25/21
# 979             Newsela       $1B     2/25/21
# 1070        Zhuan Zhuan       $1B     4/18/17
# 206             FalconX       $4B     8/10/21
#
#                                  Industry           City  Country/Region  \
# 458          Internet software & services      Chongqing           China
# 951       E-commerce & direct-to-consumer       Shenzhen           China
# 558                               Fintech  San Francisco   United States
# 653   Supply chain, logistics, & delivery       Shanghai           China
# 146                               Fintech         Berlin         Germany
# 815          Internet software & services         Berlin         Germany
# 167                               Fintech         London  United Kingdom
# 67                                Fintech         Berlin         Germany
# 424                                 Other        Boulder   United States
# 879                         Cybersecurity       New York   United States
# 103                     Consumer & retail        Beijing           China
# 198                                Health       New York   United States
# 362                               Fintech       Hangzhou           China
# 862               Artificial intelligence        Seattle   United States
# 409               Artificial intelligence   Redwood City   United States
# 201          Internet software & services      Bengaluru           India
# 181          Internet software & services  San Francisco   United States
# 140               Artificial intelligence         Irvine   United States
# 341       E-commerce & direct-to-consumer       Dongguan           China
# 806                               Fintech  Mountain View   United States
# 448                              Hardware        Waltham   United States
# 560           Data management & analytics      Sunnyvale   United States
# 982                         Cybersecurity      Palo Alto   United States
# 203           Data management & analytics       New York   United States
# 3                                 Fintech  San Francisco   United States
# 106                               Fintech      Melbourne       Australia
# 786           Data management & analytics        Seattle   United States
# 320       E-commerce & direct-to-consumer      Sao Paulo          Brazil
# 655       E-commerce & direct-to-consumer          Hefei           China
# 377                               Fintech   Peterborough  United Kingdom
# 150               Artificial intelligence  San Francisco   United States
# 694                               Fintech          Ghent         Belgium
# 704                                Health          Miami   United States
# 628                                 Other         Bogota        Colombia
# 927               Artificial intelligence  Mountain View   United States
# 68           Internet software & services         Boston   United States
# 820                              Hardware       Shanghai           China
# 854          Internet software & services        Beijing           China
# 545           Mobile & telecommunications  San Francisco   United States
# 737          Internet software & services         Dallas   United States
# 792          Internet software & services         Dublin         Ireland
# 338          Internet software & services       New York   United States
# 1009                                Other      Fort Mill   United States
# 99                                Fintech       New York   United States
# 603   Supply chain, logistics, & delivery       Shanghai           China
# 963                               Fintech       New York   United States
# 594                                Travel         Berlin         Germany
# 979          Internet software & services       New York   United States
# 1070      E-commerce & direct-to-consumer        Beijing           China
# 206                               Fintech      San Mateo   United States
#
#           Continent  Year Founded  Funding  \
# 458            Asia          2006    $445M
# 951            Asia          2011    $130M
# 558   North America          2017    $370M
# 653            Asia          2005    $800M
# 146          Europe          2015    $996M
# 815          Europe          2017    $304M
# 167          Europe          2010    $655M
# 67           Europe          2013      $2B
# 424   North America          2019  Unknown
# 879   North America          2017    $526M
# 103            Asia          1999      $2B
# 198   North America          2006    $657M
# 362            Asia          2014    $536M
# 862   North America          2016    $187M
# 409   North America          2013    $192M
# 201            Asia          2015      $1B
# 181   North America          2017    $542M
# 140   North America          2017    $691M
# 341            Asia          2014    $612M
# 806   North America          2016    $292M
# 448   North America          2011    $325M
# 560   North America          2007    $475M
# 982   North America          2020    $220M
# 203   North America          2016    $263M
# 3     North America          2010      $2B
# 106         Oceania          2015    $802M
# 786   North America          2012    $347M
# 320   South America          2011    $628M
# 655            Asia          2017    $658M
# 377          Europe          1992    $696M
# 150   North America          2013    $426M
# 694          Europe          2018    $237M
# 704   North America          2016    $241M
# 628   South America          2011    $344M
# 927   North America          2016    $362M
# 68    North America          2012    $679M
# 820            Asia          2013    $325M
# 854            Asia          2014    $300M
# 545   North America          2011    $293M
# 737   North America          2020    $215M
# 792          Europe          1999      $9M
# 338   North America          2014    $535M
# 1009  North America          2000    $250M
# 99    North America          2015    $424M
# 603            Asia          2013    $188M
# 963   North America          2017    $110M
# 594          Europe          2018    $587M
# 979   North America          2013    $172M
# 1070           Asia          2015    $990M
# 206   North America          2018    $324M
#
#                                        Select Investors
# 458                  Cybernaut Growth Fund, IDG Capital
# 951             5Y Capital, Matrix Partners China, K2VC
# 558   Andreessen Horowitz, Caffeinated Capital, SciF...
# 653                   Alibaba Group, KKR, Goldman Sachs
# 146                      Founders Fund, Accel, Creandum
# 815               HV Capital, Softbank Group, BlackRock
# 167   Accel, Technology Crossover Ventures, LeapFrog...
# 67    Redalpine Venture Partners, Earlybird Venture ...
# 424   Rubicon Technology Partners, Max Ventures, Inc...
# 879   8VC, Liberty Strategic Capital, Eden Global Pa...
# 103          Alibaba Group, Boyu Capital, Borui Capital
# 198    Qualcomm Ventures, Samsung Ventures, Silver Lake
# 362   Shunwei Capital Partners, China Media Group, G...
# 862   Madrona Venture Group, Tiger Global Management...
# 409   Smilegate Investment, DSC Investments, KTB Ven...
# 201   India Quotient, Elevation Capital, Lightspeed ...
# 181                    General Catalyst, HCA Healthcare
# 140   Andreessen Horowitz, Founders Fund, Revolution...
# 341   Matrix Partners China, Bright Venture Capita, ...
# 806   Lightspeed Venture Partners, Khosla Ventures, ...
# 448                           TPG Growth, Goldman Sachs
# 560   Nexus Venture Partners, Tenaya Capital, Sequoi...
# 982   Insight Partners, Lightspeed Venture Partners,...
# 203   Norwest Venture Partners, Goldman Sachs, Dell ...
# 3           Khosla Ventures, LowercaseCapital, capitalG
# 106   DST Global, Sequoia Capital China, Tencent Hol...
# 786   Madrona Venture Group, Kleiner Perkins Caufiel...
# 320           Kaszek Ventures, Qualcomm Ventures, Accel
# 655   Eastern Bell Capital, Capital Today, Longzhu C...
# 377                                CPP Investment Board
# 150         Venrock, Battery Ventures, Insight Partners
# 694   Newion Partners, SmartFin Capital, OMERS Ventures
# 704   Initialized Capital, Canaan Partners, Sound Ve...
# 628                                Advent International
# 927   TDK Ventures, Social Capital, D1 Capital Partners
# 68               Summit Partners, Accel, Astral Capital
# 820   BlueRun Ventures, Grand Flight Investment, Mei...
# 854               KKR, Alibaba Group, Ping An Insurance
# 545   Magma Venture Partners, Pitango Venture Capita...
# 737    Insight Partners, Sequoia Capital, Stripes Group
# 792                                                 ICG
# 338   Lightspeed Venture Partners, Lead Edge Capital...
# 1009             Silver Lake Partners, General Atlantic
# 99    Morgan Creek Digital, Marcy Venture Partners, ...
# 603   QF Capital, QC Capital, Unicom Innovation Vent...
# 963   Left Lane Capital, Galaxy Interactive, Tru Arr...
# 594   Northzone Ventures, White Star Capital, Novato...
# 979   Owl Ventures, Technology Crossover Ventures, T...
# 1070                           58.com, Tencent Holdings
# 206   Tiger Global Management, American Express Vent...

# %% [markdown]
# ### Visualize the time it took companies to reach unicorn status
#
# Visualize the longest time it took companies to reach unicorn status for each industry represented in the sample. To create a bar plot to visualize this, use the `bar()` function from the `matplotlib.pyplot` module. You'll first need to prepare the data.

# %%
unicorn = companies_sampled
unicorn
# Out:
#                 Company Valuation Date Joined  \
# 458            Zhubajie       $2B     6/16/15
# 951            Lamabang       $1B      3/6/15
# 558         Divvy Homes       $2B     8/13/21
# 653               Yiguo       $1B     11/9/16
# 146      Trade Republic       $5B     5/20/21
# 815               Enpal       $1B    10/18/21
# 167                ZEPZ       $5B     8/23/21
# 67                  N26       $9B     1/10/19
# 424             Uplight       $2B      3/3/21
# 879          BlueVoyant       $1B     2/23/22
# 103            Easyhome       $6B     2/12/18
# 198                Noom       $4B     5/24/21
# 362                Cgtz       $2B     2/21/17
# 862            Amperity       $1B     7/13/21
# 409              MOLOCO       $2B     4/29/21
# 201           ShareChat       $4B      4/8/21
# 181             Commure       $4B     9/16/21
# 140             Anduril       $5B     9/11/19
# 341            KK Group       $3B    10/23/19
# 806              At-Bay       $1B     7/27/21
# 448           Infinidat       $2B     4/29/15
# 560               Druva       $2B     6/20/19
# 982     Noname Security       $1B    12/15/21
# 203           VAST Data       $4B     4/16/20
# 3                Stripe      $95B     1/23/14
# 106           Airwallex       $6B     3/25/19
# 786              Qumulo       $1B     7/16/20
# 320           Nuvemshop       $3B     8/17/21
# 655     Yipin Shengxian       $1B     3/11/19
# 377           BGL Group       $2B    11/24/17
# 150              6Sense       $5B     3/30/21
# 694          Deliverect       $1B     1/24/22
# 704                Papa       $1B     11/4/21
# 628           LifeMiles       $1B     7/13/15
# 927                Groq       $1B     4/14/21
# 68              Klaviyo       $9B    11/17/20
# 820   Gaussian Robotics       $1B    11/10/21
# 854           58 Daojia       $1B    10/12/15
# 545           AppsFlyer       $2B     1/21/20
# 737              Island       $1B     3/23/22
# 792           Workhuman       $1B     6/23/20
# 338        Grafana Labs       $3B     3/25/21
# 1009       Red Ventures       $1B      1/7/15
# 99               Gemini       $7B    11/19/21
# 603           56PINGTAI       $1B     1/25/21
# 963         Masterworks       $1B     10/5/21
# 594                Tier       $2B    10/25/21
# 979             Newsela       $1B     2/25/21
# 1070        Zhuan Zhuan       $1B     4/18/17
# 206             FalconX       $4B     8/10/21
#
#                                  Industry           City  Country/Region  \
# 458          Internet software & services      Chongqing           China
# 951       E-commerce & direct-to-consumer       Shenzhen           China
# 558                               Fintech  San Francisco   United States
# 653   Supply chain, logistics, & delivery       Shanghai           China
# 146                               Fintech         Berlin         Germany
# 815          Internet software & services         Berlin         Germany
# 167                               Fintech         London  United Kingdom
# 67                                Fintech         Berlin         Germany
# 424                                 Other        Boulder   United States
# 879                         Cybersecurity       New York   United States
# 103                     Consumer & retail        Beijing           China
# 198                                Health       New York   United States
# 362                               Fintech       Hangzhou           China
# 862               Artificial intelligence        Seattle   United States
# 409               Artificial intelligence   Redwood City   United States
# 201          Internet software & services      Bengaluru           India
# 181          Internet software & services  San Francisco   United States
# 140               Artificial intelligence         Irvine   United States
# 341       E-commerce & direct-to-consumer       Dongguan           China
# 806                               Fintech  Mountain View   United States
# 448                              Hardware        Waltham   United States
# 560           Data management & analytics      Sunnyvale   United States
# 982                         Cybersecurity      Palo Alto   United States
# 203           Data management & analytics       New York   United States
# 3                                 Fintech  San Francisco   United States
# 106                               Fintech      Melbourne       Australia
# 786           Data management & analytics        Seattle   United States
# 320       E-commerce & direct-to-consumer      Sao Paulo          Brazil
# 655       E-commerce & direct-to-consumer          Hefei           China
# 377                               Fintech   Peterborough  United Kingdom
# 150               Artificial intelligence  San Francisco   United States
# 694                               Fintech          Ghent         Belgium
# 704                                Health          Miami   United States
# 628                                 Other         Bogota        Colombia
# 927               Artificial intelligence  Mountain View   United States
# 68           Internet software & services         Boston   United States
# 820                              Hardware       Shanghai           China
# 854          Internet software & services        Beijing           China
# 545           Mobile & telecommunications  San Francisco   United States
# 737          Internet software & services         Dallas   United States
# 792          Internet software & services         Dublin         Ireland
# 338          Internet software & services       New York   United States
# 1009                                Other      Fort Mill   United States
# 99                                Fintech       New York   United States
# 603   Supply chain, logistics, & delivery       Shanghai           China
# 963                               Fintech       New York   United States
# 594                                Travel         Berlin         Germany
# 979          Internet software & services       New York   United States
# 1070      E-commerce & direct-to-consumer        Beijing           China
# 206                               Fintech      San Mateo   United States
#
#           Continent  Year Founded  Funding  \
# 458            Asia          2006    $445M
# 951            Asia          2011    $130M
# 558   North America          2017    $370M
# 653            Asia          2005    $800M
# 146          Europe          2015    $996M
# 815          Europe          2017    $304M
# 167          Europe          2010    $655M
# 67           Europe          2013      $2B
# 424   North America          2019  Unknown
# 879   North America          2017    $526M
# 103            Asia          1999      $2B
# 198   North America          2006    $657M
# 362            Asia          2014    $536M
# 862   North America          2016    $187M
# 409   North America          2013    $192M
# 201            Asia          2015      $1B
# 181   North America          2017    $542M
# 140   North America          2017    $691M
# 341            Asia          2014    $612M
# 806   North America          2016    $292M
# 448   North America          2011    $325M
# 560   North America          2007    $475M
# 982   North America          2020    $220M
# 203   North America          2016    $263M
# 3     North America          2010      $2B
# 106         Oceania          2015    $802M
# 786   North America          2012    $347M
# 320   South America          2011    $628M
# 655            Asia          2017    $658M
# 377          Europe          1992    $696M
# 150   North America          2013    $426M
# 694          Europe          2018    $237M
# 704   North America          2016    $241M
# 628   South America          2011    $344M
# 927   North America          2016    $362M
# 68    North America          2012    $679M
# 820            Asia          2013    $325M
# 854            Asia          2014    $300M
# 545   North America          2011    $293M
# 737   North America          2020    $215M
# 792          Europe          1999      $9M
# 338   North America          2014    $535M
# 1009  North America          2000    $250M
# 99    North America          2015    $424M
# 603            Asia          2013    $188M
# 963   North America          2017    $110M
# 594          Europe          2018    $587M
# 979   North America          2013    $172M
# 1070           Asia          2015    $990M
# 206   North America          2018    $324M
#
#                                        Select Investors
# 458                  Cybernaut Growth Fund, IDG Capital
# 951             5Y Capital, Matrix Partners China, K2VC
# 558   Andreessen Horowitz, Caffeinated Capital, SciF...
# 653                   Alibaba Group, KKR, Goldman Sachs
# 146                      Founders Fund, Accel, Creandum
# 815               HV Capital, Softbank Group, BlackRock
# 167   Accel, Technology Crossover Ventures, LeapFrog...
# 67    Redalpine Venture Partners, Earlybird Venture ...
# 424   Rubicon Technology Partners, Max Ventures, Inc...
# 879   8VC, Liberty Strategic Capital, Eden Global Pa...
# 103          Alibaba Group, Boyu Capital, Borui Capital
# 198    Qualcomm Ventures, Samsung Ventures, Silver Lake
# 362   Shunwei Capital Partners, China Media Group, G...
# 862   Madrona Venture Group, Tiger Global Management...
# 409   Smilegate Investment, DSC Investments, KTB Ven...
# 201   India Quotient, Elevation Capital, Lightspeed ...
# 181                    General Catalyst, HCA Healthcare
# 140   Andreessen Horowitz, Founders Fund, Revolution...
# 341   Matrix Partners China, Bright Venture Capita, ...
# 806   Lightspeed Venture Partners, Khosla Ventures, ...
# 448                           TPG Growth, Goldman Sachs
# 560   Nexus Venture Partners, Tenaya Capital, Sequoi...
# 982   Insight Partners, Lightspeed Venture Partners,...
# 203   Norwest Venture Partners, Goldman Sachs, Dell ...
# 3           Khosla Ventures, LowercaseCapital, capitalG
# 106   DST Global, Sequoia Capital China, Tencent Hol...
# 786   Madrona Venture Group, Kleiner Perkins Caufiel...
# 320           Kaszek Ventures, Qualcomm Ventures, Accel
# 655   Eastern Bell Capital, Capital Today, Longzhu C...
# 377                                CPP Investment Board
# 150         Venrock, Battery Ventures, Insight Partners
# 694   Newion Partners, SmartFin Capital, OMERS Ventures
# 704   Initialized Capital, Canaan Partners, Sound Ve...
# 628                                Advent International
# 927   TDK Ventures, Social Capital, D1 Capital Partners
# 68               Summit Partners, Accel, Astral Capital
# 820   BlueRun Ventures, Grand Flight Investment, Mei...
# 854               KKR, Alibaba Group, Ping An Insurance
# 545   Magma Venture Partners, Pitango Venture Capita...
# 737    Insight Partners, Sequoia Capital, Stripes Group
# 792                                                 ICG
# 338   Lightspeed Venture Partners, Lead Edge Capital...
# 1009             Silver Lake Partners, General Atlantic
# 99    Morgan Creek Digital, Marcy Venture Partners, ...
# 603   QF Capital, QC Capital, Unicom Innovation Vent...
# 963   Left Lane Capital, Galaxy Interactive, Tru Arr...
# 594   Northzone Ventures, White Star Capital, Novato...
# 979   Owl Ventures, Technology Crossover Ventures, T...
# 1070                           58.com, Tencent Holdings
# 206   Tiger Global Management, American Express Vent...

# %%
unicorn['Valuation'] = unicorn['Valuation'].str.replace('$', '').str.replace('B', '')
unicorn['Valuation']
# Out:
# 458      2
# 951      1
# 558      2
# 653      1
# 146      5
# 815      1
# 167      5
# 67       9
# 424      2
# 879      1
# 103      6
# 198      4
# 362      2
# 862      1
# 409      2
# 201      4
# 181      4
# 140      5
# 341      3
# 806      1
# 448      2
# 560      2
# 982      1
# 203      4
# 3       95
# 106      6
# 786      1
# 320      3
# 655      1
# 377      2
# 150      5
# 694      1
# 704      1
# 628      1
# 927      1
# 68       9
# 820      1
# 854      1
# 545      2
# 737      1
# 792      1
# 338      3
# 1009     1
# 99       7
# 603      1
# 963      1
# 594      2
# 979      1
# 1070     1
# 206      4
# Name: Valuation, dtype: object

# %%
# Prepare data for plotting

unicorn['Valuation'] = unicorn['Valuation'].astype(int)

unicorn['Valuation']
# Out:
# 458      2
# 951      1
# 558      2
# 653      1
# 146      5
# 815      1
# 167      5
# 67       9
# 424      2
# 879      1
# 103      6
# 198      4
# 362      2
# 862      1
# 409      2
# 201      4
# 181      4
# 140      5
# 341      3
# 806      1
# 448      2
# 560      2
# 982      1
# 203      4
# 3       95
# 106      6
# 786      1
# 320      3
# 655      1
# 377      2
# 150      5
# 694      1
# 704      1
# 628      1
# 927      1
# 68       9
# 820      1
# 854      1
# 545      2
# 737      1
# 792      1
# 338      3
# 1009     1
# 99       7
# 603      1
# 963      1
# 594      2
# 979      1
# 1070     1
# 206      4
# Name: Valuation, dtype: int64

# %%
unicorn
# Out:
#                 Company  Valuation Date Joined  \
# 458            Zhubajie          2     6/16/15
# 951            Lamabang          1      3/6/15
# 558         Divvy Homes          2     8/13/21
# 653               Yiguo          1     11/9/16
# 146      Trade Republic          5     5/20/21
# 815               Enpal          1    10/18/21
# 167                ZEPZ          5     8/23/21
# 67                  N26          9     1/10/19
# 424             Uplight          2      3/3/21
# 879          BlueVoyant          1     2/23/22
# 103            Easyhome          6     2/12/18
# 198                Noom          4     5/24/21
# 362                Cgtz          2     2/21/17
# 862            Amperity          1     7/13/21
# 409              MOLOCO          2     4/29/21
# 201           ShareChat          4      4/8/21
# 181             Commure          4     9/16/21
# 140             Anduril          5     9/11/19
# 341            KK Group          3    10/23/19
# 806              At-Bay          1     7/27/21
# 448           Infinidat          2     4/29/15
# 560               Druva          2     6/20/19
# 982     Noname Security          1    12/15/21
# 203           VAST Data          4     4/16/20
# 3                Stripe         95     1/23/14
# 106           Airwallex          6     3/25/19
# 786              Qumulo          1     7/16/20
# 320           Nuvemshop          3     8/17/21
# 655     Yipin Shengxian          1     3/11/19
# 377           BGL Group          2    11/24/17
# 150              6Sense          5     3/30/21
# 694          Deliverect          1     1/24/22
# 704                Papa          1     11/4/21
# 628           LifeMiles          1     7/13/15
# 927                Groq          1     4/14/21
# 68              Klaviyo          9    11/17/20
# 820   Gaussian Robotics          1    11/10/21
# 854           58 Daojia          1    10/12/15
# 545           AppsFlyer          2     1/21/20
# 737              Island          1     3/23/22
# 792           Workhuman          1     6/23/20
# 338        Grafana Labs          3     3/25/21
# 1009       Red Ventures          1      1/7/15
# 99               Gemini          7    11/19/21
# 603           56PINGTAI          1     1/25/21
# 963         Masterworks          1     10/5/21
# 594                Tier          2    10/25/21
# 979             Newsela          1     2/25/21
# 1070        Zhuan Zhuan          1     4/18/17
# 206             FalconX          4     8/10/21
#
#                                  Industry           City  Country/Region  \
# 458          Internet software & services      Chongqing           China
# 951       E-commerce & direct-to-consumer       Shenzhen           China
# 558                               Fintech  San Francisco   United States
# 653   Supply chain, logistics, & delivery       Shanghai           China
# 146                               Fintech         Berlin         Germany
# 815          Internet software & services         Berlin         Germany
# 167                               Fintech         London  United Kingdom
# 67                                Fintech         Berlin         Germany
# 424                                 Other        Boulder   United States
# 879                         Cybersecurity       New York   United States
# 103                     Consumer & retail        Beijing           China
# 198                                Health       New York   United States
# 362                               Fintech       Hangzhou           China
# 862               Artificial intelligence        Seattle   United States
# 409               Artificial intelligence   Redwood City   United States
# 201          Internet software & services      Bengaluru           India
# 181          Internet software & services  San Francisco   United States
# 140               Artificial intelligence         Irvine   United States
# 341       E-commerce & direct-to-consumer       Dongguan           China
# 806                               Fintech  Mountain View   United States
# 448                              Hardware        Waltham   United States
# 560           Data management & analytics      Sunnyvale   United States
# 982                         Cybersecurity      Palo Alto   United States
# 203           Data management & analytics       New York   United States
# 3                                 Fintech  San Francisco   United States
# 106                               Fintech      Melbourne       Australia
# 786           Data management & analytics        Seattle   United States
# 320       E-commerce & direct-to-consumer      Sao Paulo          Brazil
# 655       E-commerce & direct-to-consumer          Hefei           China
# 377                               Fintech   Peterborough  United Kingdom
# 150               Artificial intelligence  San Francisco   United States
# 694                               Fintech          Ghent         Belgium
# 704                                Health          Miami   United States
# 628                                 Other         Bogota        Colombia
# 927               Artificial intelligence  Mountain View   United States
# 68           Internet software & services         Boston   United States
# 820                              Hardware       Shanghai           China
# 854          Internet software & services        Beijing           China
# 545           Mobile & telecommunications  San Francisco   United States
# 737          Internet software & services         Dallas   United States
# 792          Internet software & services         Dublin         Ireland
# 338          Internet software & services       New York   United States
# 1009                                Other      Fort Mill   United States
# 99                                Fintech       New York   United States
# 603   Supply chain, logistics, & delivery       Shanghai           China
# 963                               Fintech       New York   United States
# 594                                Travel         Berlin         Germany
# 979          Internet software & services       New York   United States
# 1070      E-commerce & direct-to-consumer        Beijing           China
# 206                               Fintech      San Mateo   United States
#
#           Continent  Year Founded  Funding  \
# 458            Asia          2006    $445M
# 951            Asia          2011    $130M
# 558   North America          2017    $370M
# 653            Asia          2005    $800M
# 146          Europe          2015    $996M
# 815          Europe          2017    $304M
# 167          Europe          2010    $655M
# 67           Europe          2013      $2B
# 424   North America          2019  Unknown
# 879   North America          2017    $526M
# 103            Asia          1999      $2B
# 198   North America          2006    $657M
# 362            Asia          2014    $536M
# 862   North America          2016    $187M
# 409   North America          2013    $192M
# 201            Asia          2015      $1B
# 181   North America          2017    $542M
# 140   North America          2017    $691M
# 341            Asia          2014    $612M
# 806   North America          2016    $292M
# 448   North America          2011    $325M
# 560   North America          2007    $475M
# 982   North America          2020    $220M
# 203   North America          2016    $263M
# 3     North America          2010      $2B
# 106         Oceania          2015    $802M
# 786   North America          2012    $347M
# 320   South America          2011    $628M
# 655            Asia          2017    $658M
# 377          Europe          1992    $696M
# 150   North America          2013    $426M
# 694          Europe          2018    $237M
# 704   North America          2016    $241M
# 628   South America          2011    $344M
# 927   North America          2016    $362M
# 68    North America          2012    $679M
# 820            Asia          2013    $325M
# 854            Asia          2014    $300M
# 545   North America          2011    $293M
# 737   North America          2020    $215M
# 792          Europe          1999      $9M
# 338   North America          2014    $535M
# 1009  North America          2000    $250M
# 99    North America          2015    $424M
# 603            Asia          2013    $188M
# 963   North America          2017    $110M
# 594          Europe          2018    $587M
# 979   North America          2013    $172M
# 1070           Asia          2015    $990M
# 206   North America          2018    $324M
#
#                                        Select Investors
# 458                  Cybernaut Growth Fund, IDG Capital
# 951             5Y Capital, Matrix Partners China, K2VC
# 558   Andreessen Horowitz, Caffeinated Capital, SciF...
# 653                   Alibaba Group, KKR, Goldman Sachs
# 146                      Founders Fund, Accel, Creandum
# 815               HV Capital, Softbank Group, BlackRock
# 167   Accel, Technology Crossover Ventures, LeapFrog...
# 67    Redalpine Venture Partners, Earlybird Venture ...
# 424   Rubicon Technology Partners, Max Ventures, Inc...
# 879   8VC, Liberty Strategic Capital, Eden Global Pa...
# 103          Alibaba Group, Boyu Capital, Borui Capital
# 198    Qualcomm Ventures, Samsung Ventures, Silver Lake
# 362   Shunwei Capital Partners, China Media Group, G...
# 862   Madrona Venture Group, Tiger Global Management...
# 409   Smilegate Investment, DSC Investments, KTB Ven...
# 201   India Quotient, Elevation Capital, Lightspeed ...
# 181                    General Catalyst, HCA Healthcare
# 140   Andreessen Horowitz, Founders Fund, Revolution...
# 341   Matrix Partners China, Bright Venture Capita, ...
# 806   Lightspeed Venture Partners, Khosla Ventures, ...
# 448                           TPG Growth, Goldman Sachs
# 560   Nexus Venture Partners, Tenaya Capital, Sequoi...
# 982   Insight Partners, Lightspeed Venture Partners,...
# 203   Norwest Venture Partners, Goldman Sachs, Dell ...
# 3           Khosla Ventures, LowercaseCapital, capitalG
# 106   DST Global, Sequoia Capital China, Tencent Hol...
# 786   Madrona Venture Group, Kleiner Perkins Caufiel...
# 320           Kaszek Ventures, Qualcomm Ventures, Accel
# 655   Eastern Bell Capital, Capital Today, Longzhu C...
# 377                                CPP Investment Board
# 150         Venrock, Battery Ventures, Insight Partners
# 694   Newion Partners, SmartFin Capital, OMERS Ventures
# 704   Initialized Capital, Canaan Partners, Sound Ve...
# 628                                Advent International
# 927   TDK Ventures, Social Capital, D1 Capital Partners
# 68               Summit Partners, Accel, Astral Capital
# 820   BlueRun Ventures, Grand Flight Investment, Mei...
# 854               KKR, Alibaba Group, Ping An Insurance
# 545   Magma Venture Partners, Pitango Venture Capita...
# 737    Insight Partners, Sequoia Capital, Stripes Group
# 792                                                 ICG
# 338   Lightspeed Venture Partners, Lead Edge Capital...
# 1009             Silver Lake Partners, General Atlantic
# 99    Morgan Creek Digital, Marcy Venture Partners, ...
# 603   QF Capital, QC Capital, Unicom Innovation Vent...
# 963   Left Lane Capital, Galaxy Interactive, Tru Arr...
# 594   Northzone Ventures, White Star Capital, Novato...
# 979   Owl Ventures, Technology Crossover Ventures, T...
# 1070                           58.com, Tencent Holdings
# 206   Tiger Global Management, American Express Vent...

# %%
unicorn['Valuation'] = unicorn['Valuation'] * 10000000
unicorn
# Out:
#                 Company  Valuation Date Joined  \
# 458            Zhubajie   20000000     6/16/15
# 951            Lamabang   10000000      3/6/15
# 558         Divvy Homes   20000000     8/13/21
# 653               Yiguo   10000000     11/9/16
# 146      Trade Republic   50000000     5/20/21
# 815               Enpal   10000000    10/18/21
# 167                ZEPZ   50000000     8/23/21
# 67                  N26   90000000     1/10/19
# 424             Uplight   20000000      3/3/21
# 879          BlueVoyant   10000000     2/23/22
# 103            Easyhome   60000000     2/12/18
# 198                Noom   40000000     5/24/21
# 362                Cgtz   20000000     2/21/17
# 862            Amperity   10000000     7/13/21
# 409              MOLOCO   20000000     4/29/21
# 201           ShareChat   40000000      4/8/21
# 181             Commure   40000000     9/16/21
# 140             Anduril   50000000     9/11/19
# 341            KK Group   30000000    10/23/19
# 806              At-Bay   10000000     7/27/21
# 448           Infinidat   20000000     4/29/15
# 560               Druva   20000000     6/20/19
# 982     Noname Security   10000000    12/15/21
# 203           VAST Data   40000000     4/16/20
# 3                Stripe  950000000     1/23/14
# 106           Airwallex   60000000     3/25/19
# 786              Qumulo   10000000     7/16/20
# 320           Nuvemshop   30000000     8/17/21
# 655     Yipin Shengxian   10000000     3/11/19
# 377           BGL Group   20000000    11/24/17
# 150              6Sense   50000000     3/30/21
# 694          Deliverect   10000000     1/24/22
# 704                Papa   10000000     11/4/21
# 628           LifeMiles   10000000     7/13/15
# 927                Groq   10000000     4/14/21
# 68              Klaviyo   90000000    11/17/20
# 820   Gaussian Robotics   10000000    11/10/21
# 854           58 Daojia   10000000    10/12/15
# 545           AppsFlyer   20000000     1/21/20
# 737              Island   10000000     3/23/22
# 792           Workhuman   10000000     6/23/20
# 338        Grafana Labs   30000000     3/25/21
# 1009       Red Ventures   10000000      1/7/15
# 99               Gemini   70000000    11/19/21
# 603           56PINGTAI   10000000     1/25/21
# 963         Masterworks   10000000     10/5/21
# 594                Tier   20000000    10/25/21
# 979             Newsela   10000000     2/25/21
# 1070        Zhuan Zhuan   10000000     4/18/17
# 206             FalconX   40000000     8/10/21
#
#                                  Industry           City  Country/Region  \
# 458          Internet software & services      Chongqing           China
# 951       E-commerce & direct-to-consumer       Shenzhen           China
# 558                               Fintech  San Francisco   United States
# 653   Supply chain, logistics, & delivery       Shanghai           China
# 146                               Fintech         Berlin         Germany
# 815          Internet software & services         Berlin         Germany
# 167                               Fintech         London  United Kingdom
# 67                                Fintech         Berlin         Germany
# 424                                 Other        Boulder   United States
# 879                         Cybersecurity       New York   United States
# 103                     Consumer & retail        Beijing           China
# 198                                Health       New York   United States
# 362                               Fintech       Hangzhou           China
# 862               Artificial intelligence        Seattle   United States
# 409               Artificial intelligence   Redwood City   United States
# 201          Internet software & services      Bengaluru           India
# 181          Internet software & services  San Francisco   United States
# 140               Artificial intelligence         Irvine   United States
# 341       E-commerce & direct-to-consumer       Dongguan           China
# 806                               Fintech  Mountain View   United States
# 448                              Hardware        Waltham   United States
# 560           Data management & analytics      Sunnyvale   United States
# 982                         Cybersecurity      Palo Alto   United States
# 203           Data management & analytics       New York   United States
# 3                                 Fintech  San Francisco   United States
# 106                               Fintech      Melbourne       Australia
# 786           Data management & analytics        Seattle   United States
# 320       E-commerce & direct-to-consumer      Sao Paulo          Brazil
# 655       E-commerce & direct-to-consumer          Hefei           China
# 377                               Fintech   Peterborough  United Kingdom
# 150               Artificial intelligence  San Francisco   United States
# 694                               Fintech          Ghent         Belgium
# 704                                Health          Miami   United States
# 628                                 Other         Bogota        Colombia
# 927               Artificial intelligence  Mountain View   United States
# 68           Internet software & services         Boston   United States
# 820                              Hardware       Shanghai           China
# 854          Internet software & services        Beijing           China
# 545           Mobile & telecommunications  San Francisco   United States
# 737          Internet software & services         Dallas   United States
# 792          Internet software & services         Dublin         Ireland
# 338          Internet software & services       New York   United States
# 1009                                Other      Fort Mill   United States
# 99                                Fintech       New York   United States
# 603   Supply chain, logistics, & delivery       Shanghai           China
# 963                               Fintech       New York   United States
# 594                                Travel         Berlin         Germany
# 979          Internet software & services       New York   United States
# 1070      E-commerce & direct-to-consumer        Beijing           China
# 206                               Fintech      San Mateo   United States
#
#           Continent  Year Founded  Funding  \
# 458            Asia          2006    $445M
# 951            Asia          2011    $130M
# 558   North America          2017    $370M
# 653            Asia          2005    $800M
# 146          Europe          2015    $996M
# 815          Europe          2017    $304M
# 167          Europe          2010    $655M
# 67           Europe          2013      $2B
# 424   North America          2019  Unknown
# 879   North America          2017    $526M
# 103            Asia          1999      $2B
# 198   North America          2006    $657M
# 362            Asia          2014    $536M
# 862   North America          2016    $187M
# 409   North America          2013    $192M
# 201            Asia          2015      $1B
# 181   North America          2017    $542M
# 140   North America          2017    $691M
# 341            Asia          2014    $612M
# 806   North America          2016    $292M
# 448   North America          2011    $325M
# 560   North America          2007    $475M
# 982   North America          2020    $220M
# 203   North America          2016    $263M
# 3     North America          2010      $2B
# 106         Oceania          2015    $802M
# 786   North America          2012    $347M
# 320   South America          2011    $628M
# 655            Asia          2017    $658M
# 377          Europe          1992    $696M
# 150   North America          2013    $426M
# 694          Europe          2018    $237M
# 704   North America          2016    $241M
# 628   South America          2011    $344M
# 927   North America          2016    $362M
# 68    North America          2012    $679M
# 820            Asia          2013    $325M
# 854            Asia          2014    $300M
# 545   North America          2011    $293M
# 737   North America          2020    $215M
# 792          Europe          1999      $9M
# 338   North America          2014    $535M
# 1009  North America          2000    $250M
# 99    North America          2015    $424M
# 603            Asia          2013    $188M
# 963   North America          2017    $110M
# 594          Europe          2018    $587M
# 979   North America          2013    $172M
# 1070           Asia          2015    $990M
# 206   North America          2018    $324M
#
#                                        Select Investors
# 458                  Cybernaut Growth Fund, IDG Capital
# 951             5Y Capital, Matrix Partners China, K2VC
# 558   Andreessen Horowitz, Caffeinated Capital, SciF...
# 653                   Alibaba Group, KKR, Goldman Sachs
# 146                      Founders Fund, Accel, Creandum
# 815               HV Capital, Softbank Group, BlackRock
# 167   Accel, Technology Crossover Ventures, LeapFrog...
# 67    Redalpine Venture Partners, Earlybird Venture ...
# 424   Rubicon Technology Partners, Max Ventures, Inc...
# 879   8VC, Liberty Strategic Capital, Eden Global Pa...
# 103          Alibaba Group, Boyu Capital, Borui Capital
# 198    Qualcomm Ventures, Samsung Ventures, Silver Lake
# 362   Shunwei Capital Partners, China Media Group, G...
# 862   Madrona Venture Group, Tiger Global Management...
# 409   Smilegate Investment, DSC Investments, KTB Ven...
# 201   India Quotient, Elevation Capital, Lightspeed ...
# 181                    General Catalyst, HCA Healthcare
# 140   Andreessen Horowitz, Founders Fund, Revolution...
# 341   Matrix Partners China, Bright Venture Capita, ...
# 806   Lightspeed Venture Partners, Khosla Ventures, ...
# 448                           TPG Growth, Goldman Sachs
# 560   Nexus Venture Partners, Tenaya Capital, Sequoi...
# 982   Insight Partners, Lightspeed Venture Partners,...
# 203   Norwest Venture Partners, Goldman Sachs, Dell ...
# 3           Khosla Ventures, LowercaseCapital, capitalG
# 106   DST Global, Sequoia Capital China, Tencent Hol...
# 786   Madrona Venture Group, Kleiner Perkins Caufiel...
# 320           Kaszek Ventures, Qualcomm Ventures, Accel
# 655   Eastern Bell Capital, Capital Today, Longzhu C...
# 377                                CPP Investment Board
# 150         Venrock, Battery Ventures, Insight Partners
# 694   Newion Partners, SmartFin Capital, OMERS Ventures
# 704   Initialized Capital, Canaan Partners, Sound Ve...
# 628                                Advent International
# 927   TDK Ventures, Social Capital, D1 Capital Partners
# 68               Summit Partners, Accel, Astral Capital
# 820   BlueRun Ventures, Grand Flight Investment, Mei...
# 854               KKR, Alibaba Group, Ping An Insurance
# 545   Magma Venture Partners, Pitango Venture Capita...
# 737    Insight Partners, Sequoia Capital, Stripes Group
# 792                                                 ICG
# 338   Lightspeed Venture Partners, Lead Edge Capital...
# 1009             Silver Lake Partners, General Atlantic
# 99    Morgan Creek Digital, Marcy Venture Partners, ...
# 603   QF Capital, QC Capital, Unicom Innovation Vent...
# 963   Left Lane Capital, Galaxy Interactive, Tru Arr...
# 594   Northzone Ventures, White Star Capital, Novato...
# 979   Owl Ventures, Technology Crossover Ventures, T...
# 1070                           58.com, Tencent Holdings
# 206   Tiger Global Management, American Express Vent...

# %%
unicorn = unicorn[unicorn['Valuation'] > 10000000]
unicorn
# Out:
#             Company  Valuation Date Joined                         Industry  \
# 458        Zhubajie   20000000     6/16/15     Internet software & services
# 558     Divvy Homes   20000000     8/13/21                          Fintech
# 146  Trade Republic   50000000     5/20/21                          Fintech
# 167            ZEPZ   50000000     8/23/21                          Fintech
# 67              N26   90000000     1/10/19                          Fintech
# 424         Uplight   20000000      3/3/21                            Other
# 103        Easyhome   60000000     2/12/18                Consumer & retail
# 198            Noom   40000000     5/24/21                           Health
# 362            Cgtz   20000000     2/21/17                          Fintech
# 409          MOLOCO   20000000     4/29/21          Artificial intelligence
# 201       ShareChat   40000000      4/8/21     Internet software & services
# 181         Commure   40000000     9/16/21     Internet software & services
# 140         Anduril   50000000     9/11/19          Artificial intelligence
# 341        KK Group   30000000    10/23/19  E-commerce & direct-to-consumer
# 448       Infinidat   20000000     4/29/15                         Hardware
# 560           Druva   20000000     6/20/19      Data management & analytics
# 203       VAST Data   40000000     4/16/20      Data management & analytics
# 3            Stripe  950000000     1/23/14                          Fintech
# 106       Airwallex   60000000     3/25/19                          Fintech
# 320       Nuvemshop   30000000     8/17/21  E-commerce & direct-to-consumer
# 377       BGL Group   20000000    11/24/17                          Fintech
# 150          6Sense   50000000     3/30/21          Artificial intelligence
# 68          Klaviyo   90000000    11/17/20     Internet software & services
# 545       AppsFlyer   20000000     1/21/20      Mobile & telecommunications
# 338    Grafana Labs   30000000     3/25/21     Internet software & services
# 99           Gemini   70000000    11/19/21                          Fintech
# 594            Tier   20000000    10/25/21                           Travel
# 206         FalconX   40000000     8/10/21                          Fintech
#
#               City  Country/Region      Continent  Year Founded  Funding  \
# 458      Chongqing           China           Asia          2006    $445M
# 558  San Francisco   United States  North America          2017    $370M
# 146         Berlin         Germany         Europe          2015    $996M
# 167         London  United Kingdom         Europe          2010    $655M
# 67          Berlin         Germany         Europe          2013      $2B
# 424        Boulder   United States  North America          2019  Unknown
# 103        Beijing           China           Asia          1999      $2B
# 198       New York   United States  North America          2006    $657M
# 362       Hangzhou           China           Asia          2014    $536M
# 409   Redwood City   United States  North America          2013    $192M
# 201      Bengaluru           India           Asia          2015      $1B
# 181  San Francisco   United States  North America          2017    $542M
# 140         Irvine   United States  North America          2017    $691M
# 341       Dongguan           China           Asia          2014    $612M
# 448        Waltham   United States  North America          2011    $325M
# 560      Sunnyvale   United States  North America          2007    $475M
# 203       New York   United States  North America          2016    $263M
# 3    San Francisco   United States  North America          2010      $2B
# 106      Melbourne       Australia        Oceania          2015    $802M
# 320      Sao Paulo          Brazil  South America          2011    $628M
# 377   Peterborough  United Kingdom         Europe          1992    $696M
# 150  San Francisco   United States  North America          2013    $426M
# 68          Boston   United States  North America          2012    $679M
# 545  San Francisco   United States  North America          2011    $293M
# 338       New York   United States  North America          2014    $535M
# 99        New York   United States  North America          2015    $424M
# 594         Berlin         Germany         Europe          2018    $587M
# 206      San Mateo   United States  North America          2018    $324M
#
#                                       Select Investors
# 458                 Cybernaut Growth Fund, IDG Capital
# 558  Andreessen Horowitz, Caffeinated Capital, SciF...
# 146                     Founders Fund, Accel, Creandum
# 167  Accel, Technology Crossover Ventures, LeapFrog...
# 67   Redalpine Venture Partners, Earlybird Venture ...
# 424  Rubicon Technology Partners, Max Ventures, Inc...
# 103         Alibaba Group, Boyu Capital, Borui Capital
# 198   Qualcomm Ventures, Samsung Ventures, Silver Lake
# 362  Shunwei Capital Partners, China Media Group, G...
# 409  Smilegate Investment, DSC Investments, KTB Ven...
# 201  India Quotient, Elevation Capital, Lightspeed ...
# 181                   General Catalyst, HCA Healthcare
# 140  Andreessen Horowitz, Founders Fund, Revolution...
# 341  Matrix Partners China, Bright Venture Capita, ...
# 448                          TPG Growth, Goldman Sachs
# 560  Nexus Venture Partners, Tenaya Capital, Sequoi...
# 203  Norwest Venture Partners, Goldman Sachs, Dell ...
# 3          Khosla Ventures, LowercaseCapital, capitalG
# 106  DST Global, Sequoia Capital China, Tencent Hol...
# 320          Kaszek Ventures, Qualcomm Ventures, Accel
# 377                               CPP Investment Board
# 150        Venrock, Battery Ventures, Insight Partners
# 68              Summit Partners, Accel, Astral Capital
# 545  Magma Venture Partners, Pitango Venture Capita...
# 338  Lightspeed Venture Partners, Lead Edge Capital...
# 99   Morgan Creek Digital, Marcy Venture Partners, ...
# 594  Northzone Ventures, White Star Capital, Novato...
# 206  Tiger Global Management, American Express Vent...

# %%
unicorn['Date Joined'] = pd.to_datetime(unicorn['Date Joined'])
unicorn['Year'] = unicorn['Date Joined'].dt.year

# %%
unicorn
# Out:
#             Company  Valuation Date Joined                         Industry  \
# 458        Zhubajie   20000000  2015-06-16     Internet software & services
# 558     Divvy Homes   20000000  2021-08-13                          Fintech
# 146  Trade Republic   50000000  2021-05-20                          Fintech
# 167            ZEPZ   50000000  2021-08-23                          Fintech
# 67              N26   90000000  2019-01-10                          Fintech
# 424         Uplight   20000000  2021-03-03                            Other
# 103        Easyhome   60000000  2018-02-12                Consumer & retail
# 198            Noom   40000000  2021-05-24                           Health
# 362            Cgtz   20000000  2017-02-21                          Fintech
# 409          MOLOCO   20000000  2021-04-29          Artificial intelligence
# 201       ShareChat   40000000  2021-04-08     Internet software & services
# 181         Commure   40000000  2021-09-16     Internet software & services
# 140         Anduril   50000000  2019-09-11          Artificial intelligence
# 341        KK Group   30000000  2019-10-23  E-commerce & direct-to-consumer
# 448       Infinidat   20000000  2015-04-29                         Hardware
# 560           Druva   20000000  2019-06-20      Data management & analytics
# 203       VAST Data   40000000  2020-04-16      Data management & analytics
# 3            Stripe  950000000  2014-01-23                          Fintech
# 106       Airwallex   60000000  2019-03-25                          Fintech
# 320       Nuvemshop   30000000  2021-08-17  E-commerce & direct-to-consumer
# 377       BGL Group   20000000  2017-11-24                          Fintech
# 150          6Sense   50000000  2021-03-30          Artificial intelligence
# 68          Klaviyo   90000000  2020-11-17     Internet software & services
# 545       AppsFlyer   20000000  2020-01-21      Mobile & telecommunications
# 338    Grafana Labs   30000000  2021-03-25     Internet software & services
# 99           Gemini   70000000  2021-11-19                          Fintech
# 594            Tier   20000000  2021-10-25                           Travel
# 206         FalconX   40000000  2021-08-10                          Fintech
#
#               City  Country/Region      Continent  Year Founded  Funding  \
# 458      Chongqing           China           Asia          2006    $445M
# 558  San Francisco   United States  North America          2017    $370M
# 146         Berlin         Germany         Europe          2015    $996M
# 167         London  United Kingdom         Europe          2010    $655M
# 67          Berlin         Germany         Europe          2013      $2B
# 424        Boulder   United States  North America          2019  Unknown
# 103        Beijing           China           Asia          1999      $2B
# 198       New York   United States  North America          2006    $657M
# 362       Hangzhou           China           Asia          2014    $536M
# 409   Redwood City   United States  North America          2013    $192M
# 201      Bengaluru           India           Asia          2015      $1B
# 181  San Francisco   United States  North America          2017    $542M
# 140         Irvine   United States  North America          2017    $691M
# 341       Dongguan           China           Asia          2014    $612M
# 448        Waltham   United States  North America          2011    $325M
# 560      Sunnyvale   United States  North America          2007    $475M
# 203       New York   United States  North America          2016    $263M
# 3    San Francisco   United States  North America          2010      $2B
# 106      Melbourne       Australia        Oceania          2015    $802M
# 320      Sao Paulo          Brazil  South America          2011    $628M
# 377   Peterborough  United Kingdom         Europe          1992    $696M
# 150  San Francisco   United States  North America          2013    $426M
# 68          Boston   United States  North America          2012    $679M
# 545  San Francisco   United States  North America          2011    $293M
# 338       New York   United States  North America          2014    $535M
# 99        New York   United States  North America          2015    $424M
# 594         Berlin         Germany         Europe          2018    $587M
# 206      San Mateo   United States  North America          2018    $324M
#
#                                       Select Investors  Year
# 458                 Cybernaut Growth Fund, IDG Capital  2015
# 558  Andreessen Horowitz, Caffeinated Capital, SciF...  2021
# 146                     Founders Fund, Accel, Creandum  2021
# 167  Accel, Technology Crossover Ventures, LeapFrog...  2021
# 67   Redalpine Venture Partners, Earlybird Venture ...  2019
# 424  Rubicon Technology Partners, Max Ventures, Inc...  2021
# 103         Alibaba Group, Boyu Capital, Borui Capital  2018
# 198   Qualcomm Ventures, Samsung Ventures, Silver Lake  2021
# 362  Shunwei Capital Partners, China Media Group, G...  2017
# 409  Smilegate Investment, DSC Investments, KTB Ven...  2021
# 201  India Quotient, Elevation Capital, Lightspeed ...  2021
# 181                   General Catalyst, HCA Healthcare  2021
# 140  Andreessen Horowitz, Founders Fund, Revolution...  2019
# 341  Matrix Partners China, Bright Venture Capita, ...  2019
# 448                          TPG Growth, Goldman Sachs  2015
# 560  Nexus Venture Partners, Tenaya Capital, Sequoi...  2019
# 203  Norwest Venture Partners, Goldman Sachs, Dell ...  2020
# 3          Khosla Ventures, LowercaseCapital, capitalG  2014
# 106  DST Global, Sequoia Capital China, Tencent Hol...  2019
# 320          Kaszek Ventures, Qualcomm Ventures, Accel  2021
# 377                               CPP Investment Board  2017
# 150        Venrock, Battery Ventures, Insight Partners  2021
# 68              Summit Partners, Accel, Astral Capital  2020
# 545  Magma Venture Partners, Pitango Venture Capita...  2020
# 338  Lightspeed Venture Partners, Lead Edge Capital...  2021
# 99   Morgan Creek Digital, Marcy Venture Partners, ...  2021
# 594  Northzone Ventures, White Star Capital, Novato...  2021
# 206  Tiger Global Management, American Express Vent...  2021

# %%
a = unicorn.groupby('Industry').max('Year')
a
# Out:
#                                  Valuation  Year Founded  Year
# Industry
# Artificial intelligence           50000000          2017  2021
# Consumer & retail                 60000000          1999  2018
# Data management & analytics       40000000          2016  2020
# E-commerce & direct-to-consumer   30000000          2014  2021
# Fintech                          950000000          2018  2021
# Hardware                          20000000          2011  2015
# Health                            40000000          2006  2021
# Internet software & services      90000000          2017  2021
# Mobile & telecommunications       20000000          2011  2020
# Other                             20000000          2019  2021
# Travel                            20000000          2018  2021

# %%
a = a.reset_index()
a
# Out:
#                            Industry  Valuation  Year Founded  Year
# 0           Artificial intelligence   50000000          2017  2021
# 1                 Consumer & retail   60000000          1999  2018
# 2       Data management & analytics   40000000          2016  2020
# 3   E-commerce & direct-to-consumer   30000000          2014  2021
# 4                           Fintech  950000000          2018  2021
# 5                          Hardware   20000000          2011  2015
# 6                            Health   40000000          2006  2021
# 7      Internet software & services   90000000          2017  2021
# 8       Mobile & telecommunications   20000000          2011  2020
# 9                             Other   20000000          2019  2021
# 10                           Travel   20000000          2018  2021

# %%
# Create bar plot
# with the various industries as the categories of the bars
# and the time it took to reach unicorn status as the height of the bars

plt.bar(a['Industry'], a['Year']-a['Year Founded'])

plt.title('Time To Reach Unicorn Status')

plt.xticks(rotation=45, horizontalalignment='right')
# Set title



# Set x-axis label

plt.xlabel('Unicorn Companies')

# Set y-axis label

plt.ylabel('Time to Reach')

# Rotate labels on the x-axis as a way to avoid overlap in the positions of the text


# Display the plot

plt.show()

# %% [markdown]
# <details>
#   <summary><h4><strong>Hint 1</strong></h4></summary>
#
# To prepare the data for modeling, begin by creating a column that represents the number of years it took each company to reach unicorn status.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Hint 2</strong></h4></summary>
#
# To prepare the data for modeling, group the dataframe by industry and get the maximum value in the newly created column for each industry.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Hint 3</strong></h4></summary>
#
# You can use the `plt.bar()` to create the bar plot, passing in the categories and heights of the bars.
#
# You can use `plt.title()`, `plt.xlabel()`, and `plt.ylabel()` to set the title, x-axis label, and y-axis label, respectively.
#
# You can use `plt.xticks()` to rotate labels on the x-axis of a plot. The parameters `rotation=45, horizontalalignment='right'` can be passed in to rotate the labels by 45 degrees and align the labels to the right.
#
# You can use `plt.show()` to display a plot.
#
# </details>

# %% [markdown]
# **Question:** What do you observe from this bar plot?

# %% [markdown]
# Consumer and retail spent more than 17.5 years to reach out.

# %% [markdown]
# ### Visualize the maximum unicorn company valuation per industry
#
# Visualize unicorn companies' maximum valuation for each industry represented in the sample. To create a bar plot to visualize this, use the `bar()` function from the `matplotlib.pyplot` module. Before plotting, create a new column that represents the companies' valuations as numbers (instead of strings, as they're currently represented). Then, use this new column to plot your data.

# %%
b = unicorn.groupby('Industry').max('Valuation').reset_index()
b
# Out:
#                            Industry  Valuation  Year Founded  Year
# 0           Artificial intelligence   50000000          2017  2021
# 1                 Consumer & retail   60000000          1999  2018
# 2       Data management & analytics   40000000          2016  2020
# 3   E-commerce & direct-to-consumer   30000000          2014  2021
# 4                           Fintech  950000000          2018  2021
# 5                          Hardware   20000000          2011  2015
# 6                            Health   40000000          2006  2021
# 7      Internet software & services   90000000          2017  2021
# 8       Mobile & telecommunications   20000000          2011  2020
# 9                             Other   20000000          2019  2021
# 10                           Travel   20000000          2018  2021

# %%
# Create bar plot
# with the various industries as the categories of the bars
# and the maximum valuation for each industry as the height of the bars

plt.bar(b['Industry'], b['Valuation'])

# Set title

plt.title('Maximum Valuation Companies')

# Set x-axis label

plt.xlabel('Companies')

# Set y-axis label

plt.ylabel('Valuation')

# Rotate labels on the x-axis as a way to avoid overlap in the positions of the text  

plt.xticks(rotation=45, horizontalalignment='right')

# Display the plot

plt.show()

# %% [markdown]
# <details>
#   <summary><h4><strong>Hint 1</strong></h4></summary>
#
# Repeat the process from the last task, only this time with different variables.
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Hint 2</strong></h4></summary>
#
# Use the function in the `matplotlib.pyplot` module that allows you to create a bar plot, specifying the category and height for each bar.
#
# Use the functions in the `matplotlib.pyplot` module that allow you to set the title, x-axis label, and y-axis label of plots. In that module, there are also functions for rotating the labels on the x-axis and displaying the plot.
#
# </details>

# %% [markdown]
# <details>
#   <summary><h4><strong>Hint 3</strong></h4></summary>
#
# Use the `plt.bar()` to create the bar plot, passing in the categories and heights of the bars.
#
# Use `plt.title()`, `plt.xlabel()`, and `plt.ylabel()` to set the title, x-axis label, and y-axis label, respectively.
#
# Use `plt.xticks()` to rotate labels on the x-axis of a plot. The parameters `rotation=45, horizontalalignment='right'` can be passed in to rotate the labels by 45 degrees and align the labels to the right.
#
# Use `plt.show()` to display a plot.
#
# </details>

# %% [markdown]
# **Question:** What do you observe from this bar plot?

# %% [markdown]
# Fintech Valuation is extremely superior rather than other companies

# %% [markdown]
# ## Considerations

# %% [markdown]
# **What are some key takeaways that you learned from this lab?**

# %% [markdown]
# [Write your response here. Double-click (or enter) to edit.]

# %% [markdown]
# **What findings would you share with others?**

# %% [markdown]
# [Write your response here. Double-click (or enter) to edit.]

# %% [markdown]
# **What recommendations would you share with stakeholders based on these findings?**

# %% [markdown]
# [Write your response here. Double-click (or enter) to edit.]

# %% [markdown]
# **References**
#
# Bhat, M.A. (2022, March). [*Unicorn Companies*](https://www.kaggle.com/datasets/mysarahmadbhat/unicorn-companies).

# %% [markdown]
# **Congratulations!** You've completed this lab. However, you may not notice a green check mark next to this item on Coursera's platform. Please continue your progress regardless of the check mark. Just click on the "save" icon at the top of this notebook to ensure your work has been logged.
